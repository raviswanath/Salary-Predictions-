# %% [markdown]
# # Salary Predictions Based on Job Descriptions

# %% [markdown]
# The goal of this project is to develop a model that ingests features like company information, candidate qualification, degree etc to predict the salary of a particular role defined uniquely by a jobId.

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# Scikit Learn pre-processing libraries needed
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

# sklearn ML libraries 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso
import xgboost as xgb

# New regression base lib which helps with building visuals of the results
from yellowbrick.regressor import ResidualsPlot


# author info 
__author__ = "Aadithya Ramasubramaniam"
__email__ = "aadithya.viswanath@gmail.com"

# %% [markdown]
# ### ---- Loading the data ----

# %%
# load the data into a Pandas dataframe
Test_Features = pd.read_csv('/Users/raviswanath/Dropbox/data/test_features.csv')
Train_Features = pd.read_csv('/Users/raviswanath/Dropbox/data/train_features.csv')
Train_Salaries = pd.read_csv('/Users/raviswanath/Dropbox/data/train_salaries.csv')

# %% [markdown]
# ### ---- Data cleaning and exploration ----

# %%
Train_Features.head()
# Out:
#               jobId companyId         jobType       degree      major  \
# 0  JOB1362684407687    COMP37             CFO      MASTERS       MATH
# 1  JOB1362684407688    COMP19             CEO  HIGH_SCHOOL       NONE
# 2  JOB1362684407689    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS
# 3  JOB1362684407690    COMP38         MANAGER     DOCTORAL  CHEMISTRY
# 4  JOB1362684407691     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS
#
#   industry  yearsExperience  milesFromMetropolis
# 0   HEALTH               10                   83
# 1      WEB                3                   73
# 2   HEALTH               10                   38
# 3     AUTO                8                   17
# 4  FINANCE                8                   16

# %%
Train_Salaries.head()
# Out:
#               jobId  salary
# 0  JOB1362684407687     130
# 1  JOB1362684407688     101
# 2  JOB1362684407689     137
# 3  JOB1362684407690     142
# 4  JOB1362684407691     163

# %%
Train_Features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
# jobId                  1000000 non-null object
# companyId              1000000 non-null object
# jobType                1000000 non-null object
# degree                 1000000 non-null object
# major                  1000000 non-null object
# industry               1000000 non-null object
# yearsExperience        1000000 non-null int64
# milesFromMetropolis    1000000 non-null int64
# dtypes: int64(2), object(6)
# memory usage: 61.0+ MB

# %%
Train_Salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 2 columns):
# jobId     1000000 non-null object
# salary    1000000 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 15.3+ MB

# %%
# merge relevant salary and job features info into a single data set
Training_data = Train_Features.merge(Train_Salaries, on="jobId")

# %%
# checking for missing data
Training_data.isnull().sum()/len(Training_data)
# Out:
# jobId                  0.0
# companyId              0.0
# jobType                0.0
# degree                 0.0
# major                  0.0
# industry               0.0
# yearsExperience        0.0
# milesFromMetropolis    0.0
# salary                 0.0
# dtype: float64

# %% [markdown]
# ### Check and remove outliers

# %%
numeric_cols = Training_data.select_dtypes(exclude='object')
categoriacl_cols = Training_data.select_dtypes(exclude=['int64', 'float64'])

# %%
[cols for cols in numeric_cols.columns if (numeric_cols[cols] <= 0).any()]
# Out:
# ['yearsExperience', 'milesFromMetropolis', 'salary']

# %%
Training_data[Training_data.salary <=0]
# Out:
#                    jobId companyId         jobType       degree        major  \
# 30559   JOB1362684438246    COMP44          JUNIOR     DOCTORAL         MATH
# 495984  JOB1362684903671    COMP34          JUNIOR         NONE         NONE
# 652076  JOB1362685059763    COMP25             CTO  HIGH_SCHOOL         NONE
# 816129  JOB1362685223816    COMP42         MANAGER     DOCTORAL  ENGINEERING
# 828156  JOB1362685235843    COMP40  VICE_PRESIDENT      MASTERS  ENGINEERING
#
#        industry  yearsExperience  milesFromMetropolis  salary
# 30559      AUTO               11                    7       0
# 495984      OIL                1                   25       0
# 652076     AUTO                6                   60       0
# 816129  FINANCE               18                    6       0
# 828156      WEB                3                   29       0

# %%
Train_Features[Train_Features.yearsExperience < 0]
# Out:
# Empty DataFrame
# Columns: [jobId, companyId, jobType, degree, major, industry, yearsExperience, milesFromMetropolis]
# Index: []

# %%
Train_Features[Train_Features.milesFromMetropolis < 0]
# Out:
# Empty DataFrame
# Columns: [jobId, companyId, jobType, degree, major, industry, yearsExperience, milesFromMetropolis]
# Index: []

# %%
# Removing rows with salary = 0
Training_data = Training_data[Training_data.salary > 0]

# %%
Training_data.jobType.value_counts()
# Out:
# SENIOR            125886
# VICE_PRESIDENT    125234
# MANAGER           125120
# CTO               125045
# JANITOR           124971
# CEO               124778
# JUNIOR            124592
# CFO               124369
# Name: jobType, dtype: int64

# %%
Training_data.groupby(['jobType'])['yearsExperience', 'salary'].median()
# Out:
#                 yearsExperience  salary
# jobType
# CEO                          12     142
# CFO                          12     132
# CTO                          12     132
# JANITOR                      12      68
# JUNIOR                       12      92
# MANAGER                      12     112
# SENIOR                       12     102
# VICE_PRESIDENT               12     122

# %%
# Function to remove records which have less than x% of rows in a certain salary range

def remove_extremes(Training_data, tune_param):
    '''Function to remove records which have less than x% of rows in a certain salary range'''
    
    rows_removed = 0
    Job_Types = Training_data.jobType.unique()
    
    for j in Job_Types:
        x = Training_data[Training_data.jobType==j]['salary'].count()
        for i in range(0, 100, 10):
            #identify records in the certain bin for jobType j
            y = Training_data[(Training_data.jobType == j) &
                (Training_data.salary >= np.percentile(Training_data.salary, i)) & 
                (Training_data.salary < np.percentile(Training_data.salary, (i+10)))]['salary'].count()

            if((y/x)*100 < tune_param):
                    # keep count of the number of rows removed
                    rows_removed = rows_removed + y

                    # eliminate the records
                    Training_data = Training_data.loc[~((Training_data.jobType == j)&
                                    (Training_data.salary >= np.percentile(Training_data.salary, i))&
                                    (Training_data.salary < np.percentile(Training_data.salary, (i+10)))),:]
    print(rows_removed)
    return(Training_data)

# %%
# Change the tuning parameter here to remove more and more rows. 
Training_data = remove_extremes(Training_data, 2.5)
# Out:
# 9587

# %%
Training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 990408 entries, 0 to 999999
# Data columns (total 9 columns):
# jobId                  990408 non-null object
# companyId              990408 non-null object
# jobType                990408 non-null object
# degree                 990408 non-null object
# major                  990408 non-null object
# industry               990408 non-null object
# yearsExperience        990408 non-null int64
# milesFromMetropolis    990408 non-null int64
# salary                 990408 non-null int64
# dtypes: int64(3), object(6)
# memory usage: 75.6+ MB

# %%
# Removing all entries with salaries greater than 250
Training_data = Training_data[Training_data.salary < 250]

# %%
Training_data.head()
# Out:
#               jobId companyId         jobType       degree      major  \
# 0  JOB1362684407687    COMP37             CFO      MASTERS       MATH
# 1  JOB1362684407688    COMP19             CEO  HIGH_SCHOOL       NONE
# 2  JOB1362684407689    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS
# 3  JOB1362684407690    COMP38         MANAGER     DOCTORAL  CHEMISTRY
# 4  JOB1362684407691     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS
#
#   industry  yearsExperience  milesFromMetropolis  salary
# 0   HEALTH               10                   83     130
# 1      WEB                3                   73     101
# 2   HEALTH               10                   38     137
# 3     AUTO                8                   17     142
# 4  FINANCE                8                   16     163

# %% [markdown]
# ### ----4 EDA ----

# %%
# Distribution of salary 
sns.set(style="darkgrid")
sns.distplot(Training_data.salary)
plt.title("Distribution of salary")
plt.show()

# %% [markdown]
# Distribution of salary is almost normal (marginally right skewed) with the long tail extending beyond the 250k mark.

# %%
# correlation between numeric variables
subset = Training_data[['salary', 'yearsExperience', 'milesFromMetropolis']]
subset.corr()
# Out:
#                        salary  yearsExperience  milesFromMetropolis
# salary               1.000000         0.367124            -0.289967
# yearsExperience      0.367124         1.000000             0.012306
# milesFromMetropolis -0.289967         0.012306             1.000000

# %% [markdown]
# As one would expect, salary is positively correlated with years of experience.
#
# Also, the farther the job is located from the metropolis (city), the lower the salary becomes. This is also inline with the intuition that living expenes are usually more in and around the metro and jobs need to be paying higher in the city area to remain attractive.

# %%
# Pay distribuition across titles
g = sns.FacetGrid(Training_data, col='jobType', height=4)
g = g.map(plt.hist, 'salary', bins=10)

# %% [markdown]
# A summary of salary distributions which gives an idea of the salary ranges for each of the job types in our data set.
#
# CEO's have a right skewed salary distribution with salaries ranging from ~90k to 250k. The same could be said for CFO's, CTO's and VP's, however, the minimum salary for all these positions are significantly lower when compared to the CEO as shown by the plots.
#
# Janitors have the lowest salary range with some of them making well beyond the 100k mark. One would expect such jobs to be in the heart of a metropolis and requiring a lot of experience.

# %%
# The percentage of each of the job titles in the dataset
(Training_data.jobType.value_counts()/len(Training_data))*100
# Out:
# SENIOR            12.721441
# MANAGER           12.642718
# CTO               12.585418
# CFO               12.519327
# VICE_PRESIDENT    12.514173
# CEO               12.397756
# JUNIOR            12.384113
# JANITOR           12.235054
# Name: jobType, dtype: float64

# %% [markdown]
# The data is uniform across all job types. We have almost equal number of records for the model to be trained on across all positions.

# %%
# Median salary by Job Title
from matplotlib import rcParams
rcParams['figure.figsize'] = 12, 6
sns.barplot(x='jobType', 
            y='salary',
            data=Training_data.groupby(['jobType'])['salary'].median().reset_index().sort_values(by='salary'))
plt.title('Salary by Job Title')
plt.xlabel('Job Title')
plt.ylabel('Salary k$')
plt.show()

# %% [markdown]
# As one would expect, the pay structure grows with the title. CEO's get paid the most (on average) and Janitors the least.

# %%
# Relationship between salary and years of experience
sns.scatterplot(x='yearsExperience',
                y='salary',
                data=Training_data)

plt.xlabel("Years of Experience")
plt.ylabel("Salary (k$)")
plt.title("Years of Experience vs Salary")
plt.show()

# %% [markdown]
# A gradual shift in the salary levels can be seen as the experience increases which is inline with expectations.

# %%
# Avg salary by industry
sns.boxplot(x='industry',
            y='salary',
            data = Training_data)
plt.xlabel('Industry')
plt.ylabel('Salary (k$)')
plt.title("Salary by Industry")
plt.show()

# %% [markdown]
# Finance industry jobs pay the highest on average, closely followed by Oil, while Education sector pays the least.

# %%
# Avg. Salary by Industry and Title
sns.barplot(x='industry',
            y='salary',
            hue='jobType',
            data=Training_data.groupby(['industry', 
                                        'jobType'])['salary'].median().reset_index().sort_values(['industry',
                                                                                                  'salary'], ascending=True))
plt.xlabel('Industry')
plt.ylabel('Salary (k$)')
plt.title('Avg salary by Industry and Title')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# Distribution of pay by industry and title
rcParams['figure.figsize'] = 14, 6
sns.boxplot(x='industry',
            y='salary',
            hue='jobType',
            data=Training_data)
plt.title('Salary Distribution by Industry and Title')
plt.xlabel('Industry')
plt.ylabel('Salary (k$)')
plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.)
plt.show()

# %%
# Least paying industries and titles
sns.barplot(x="industry", 
            y='salary', 
            hue='jobType',
            data=Training_data[['jobType', 'salary', 'industry']].sort_values('salary', ascending=True).head(50))
plt.xlabel('Industry')
plt.ylabel('Salary (k$)')
plt.title('Least paying Industries and titles')
plt.show()

# %%
# How important is having a degree to be earning more?
Training_data.degree.value_counts()/ len(Training_data)
# Out:
# HIGH_SCHOOL    0.236233
# NONE           0.235220
# BACHELORS      0.176515
# MASTERS        0.176182
# DOCTORAL       0.175851
# Name: degree, dtype: float64

# %%
# How important is having a degree to be earning more?
sns.boxplot(x='degree',
            y='salary',
            data = Training_data,
            order = ["NONE", "HIGH_SCHOOL", "BACHELORS", "MASTERS", "DOCTORAL"])
plt.xlabel('Degree')
plt.ylabel('Salary (k$)')
plt.title('Variation in salary by degree')
plt.show()

# %% [markdown]
# The above plot clearly shows that having degree helps with getting paid more. The higher the level of degree held, the higher the salary.
#
# However, the same cannot be said for highest pay. At the top level, observations can be found which imply that one need not have a degree at all for earning above 200k.

# %%
# But are there C-level executives without even a Bachelor's degree?
Training_data[(Training_data.degree == "NONE") | 
              (Training_data.degree == "HIGH_SCHOOL")].groupby(['jobType'])['salary'].count()
# Out:
# jobType
# CEO                48193
# CFO                49309
# CTO                49453
# JANITOR           121071
# JUNIOR             49742
# MANAGER            49987
# SENIOR             49963
# VICE_PRESIDENT     48804
# Name: salary, dtype: int64

# %%
# Distribution of years of experience
Training_data.yearsExperience.hist()
plt.title("Years of Experience")
plt.show()

# %%
# relationship between job title and distance from Metro
sns.violinplot(x='jobType',
               y='milesFromMetropolis',
               data=Training_data,
               order=['JANITOR','JUNIOR', 'SENIOR', 'MANAGER', 'VICE_PRESIDENT',
                     'CTO', 'CFO', 'CEO'])
plt.title('How far do different employees live from Metro')
plt.xlabel('Job Title')
plt.ylabel('Distance to city')
plt.show()

# %% [markdown]
# The dataset has positions uniformly spread across distances.The violin plot above is uniformly stretched out all across for all titles, implying we have almost equal number of records with distance from metro varying between 0 and 100.

# %%
# Janitors and Junirs who earn more
Js = ['JANITOR', 'JUNIOR']
Training_data[(Training_data.jobType.isin(Js)) &
             (Training_data.salary >= 100)].groupby(['jobType'])['salary', 'yearsExperience'].mean()
# Out:
#              salary  yearsExperience
# jobType
# JANITOR  109.387384        18.377180
# JUNIOR   121.554035        15.356461

# %%
# Exce's who earn less
Executives = ["CEO", "CFO", "CTO", "VICE_PRESIDENT"]
Training_data[(Training_data.jobType.isin(Executives)) & 
              (Training_data.salary <= 100)].groupby(['jobType'])['salary', 'yearsExperience'].mean()
# Out:
#                    salary  yearsExperience
# jobType
# CEO             93.230579         6.836761
# CFO             89.474938         7.169047
# CTO             89.465499         7.162604
# VICE_PRESIDENT  88.005250         7.888040

# %%
# Do a particular major grads earn more as compared to the others?
Training_data.major.value_counts()
# Out:
# NONE           524824
# CHEMISTRY       58602
# LITERATURE      58505
# PHYSICS         58145
# BIOLOGY         58138
# COMPSCI         58092
# BUSINESS        57926
# ENGINEERING     57850
# MATH            57460
# Name: major, dtype: int64

# %%
Training_data.degree.value_counts()
# Out:
# HIGH_SCHOOL    233762
# NONE           232760
# BACHELORS      174669
# MASTERS        174339
# DOCTORAL       174012
# Name: degree, dtype: int64

# %%
# Do a particular major grads earn more as compared to the others?
sns.boxplot(x='major',
            y='salary',
            data=Training_data)
plt.xlabel('Major')
plt.ylabel('Salary (k$)')
plt.title('Salary by Major')
plt.show()

# %% [markdown]
# Having a math, business or engineering degree seems to have strong correlation with getting paid more. All other majors rack up almost at the same level except for Literature.
#
# This makes sense because it is highly likely that candidates with a literature degree would most likely be employed in the education or health sector, which are low paying industries.
#
# The NONE segment seems to be a little underpaid overall because the correlation between having no degree and being employed as a Janitor is high.

# %% [markdown]
# ### ---- 5 Establish a baseline ----

# %%
#select a reasonable metric (MSE in this case)
#create an extremely simple model and measure its efficacy
#e.g. use "average salary" for each industry as your model and then measure MSE
#during 5-fold cross-validation

# %%
# creating baseline values
Baseline_salary = Training_data.groupby(['industry', 'jobType'])['salary'].median().reset_index()
Baseline_data = Training_data
salary = Baseline_data['salary']
Baseline_data.drop('salary', axis=1, inplace=True)

# %%
# Splitting the data to training and test sets
train_predictors, test_predictors, train_salary, test_salary = train_test_split(Baseline_data, 
                                                                                salary, 
                                                                                test_size=0.3,
                                                                                random_state=42)

# %%
# Select categorical columns and check their cardinality
categorical_cols = [cols for cols in train_predictors.columns 
                   if train_predictors[cols].dtype == 'object']

# cardinality
for col in categorical_cols:
    print(col, ":", train_predictors[col].nunique())
# Out:
# jobId : 692679
# companyId : 63
# jobType : 8
# degree : 5
# major : 9
# industry : 7

# %%
# only keep columns which have a cardinality < 10
categorical_cols = [col for col in categorical_cols 
                   if train_predictors[col].nunique() <= 10]

# numerical cols
numeric_cols = [col for col in train_predictors.columns
               if train_predictors[col].dtype in ["int64", "float64"]]

# %%
# Fitting a basic regression model
basic_model = LinearRegression()

# %%
# one hot encoding categorical features
New_data = pd.get_dummies(train_predictors[categorical_cols])

train_predictors = train_predictors.select_dtypes(exclude=['object'])
train_predictors = pd.concat([train_predictors, New_data], axis=1)

# %%
# Fitting a basic regression model
basic_model = LinearRegression()
cv_results = cross_val_score(basic_model, train_predictors, 
                            train_salary,
                            cv=5)

# %%
# r2 values for 5-fold CV
cv_results
# Out:
# array([0.74394952, 0.74644446, 0.74389   , 0.74442228, 0.74309522])

# %%
# making predictions and comparing results against baseline averages

avg_sal_test = test_predictors.merge(Baseline_salary, on=['industry', 'jobType'])
avg_sal_test = avg_sal_test['salary']

# preparing the test set for making predictions
test_predictors_encodes = pd.get_dummies(test_predictors[categorical_cols])
test_predictors = test_predictors.select_dtypes(exclude=['object'])
test_predictors = pd.concat([test_predictors, test_predictors_encodes], axis=1)

# making predictions and finding the MSE 
basic_model.fit(train_predictors, train_salary)
basic_predictions = basic_model.predict(test_predictors)
mean_squared_error(test_salary, basic_predictions)
# Out:
# 376.2205424059204

# %%
# regression with residual plot
v = ResidualsPlot(LinearRegression())
v.fit(train_predictors, train_salary)
v.score(test_predictors, test_salary)
v.poof()

# %%
# Model efficacy (compared to a basline model)
mean_squared_error(test_salary, avg_sal_test)
# Out:
# 2170.0109680222863

# %%
# % Improvement offered over a simple baseline solution
(abs(mean_squared_error(test_salary, avg_sal_test) - 
    mean_squared_error(test_salary, basic_predictions))/ (mean_squared_error(test_salary, avg_sal_test)))*100
# Out:
# 82.6627354446599

# %% [markdown]
# ### ---- 6 Hypothesize solution ----

# %% [markdown]
# ## Part 3 - DEVELOP

# %% [markdown]
# You will cycle through creating features, tuning models, and training/validing models (steps 7-9) until you've reached your efficacy goal
#
# #### Your metric will be MSE and your goal is:
#  - <360 for entry-level data science roles
#  - <320 for senior data science roles

# %% [markdown]
# ### ---- 7 Engineer features  ----

# %%
#make sure that data is ready for modeling
#create any new features needed to potentially enhance model

# %%
# converting the training records into numpy arrays to enhance processing speed
feature_list = list(train_predictors.columns)
train_predictors = np.array(train_predictors)
test_predictors = np.array(test_predictors)

train_salary = np.array(train_salary)
test_salary = np.array(test_salary)

# %%
train_predictors
# Out:
# array([[16, 79,  0, ...,  0,  0,  0],
#        [ 4, 70,  0, ...,  0,  0,  0],
#        [11, 14,  0, ...,  0,  0,  0],
#        ...,
#        [10, 46,  0, ...,  1,  0,  0],
#        [14, 16,  1, ...,  0,  0,  0],
#        [12,  2,  0, ...,  0,  0,  0]])

# %% [markdown]
# ### ---- 9 Test models ----

# %% [markdown]
# ### Cross validation and tuning with Lasso

# %%
from sklearn.linear_model import LassoCV
l1_cv = LassoCV(n_jobs=-1,
               cv=5, max_iter=100, 
               random_state=42)

# %%
l1_cv.fit(train_predictors, train_salary)
# Out:
# LassoCV(alphas=None, copy_X=True, cv=5, eps=0.001, fit_intercept=True,
#     max_iter=100, n_alphas=100, n_jobs=-1, normalize=False, positive=False,
#     precompute='auto', random_state=42, selection='cyclic', tol=0.0001,
#     verbose=False)

# %%
l1_cv.alpha_
# Out:
# 0.32047919763902105

# %%
l1_cv_predictions = l1_cv.predict(test_predictors)
mean_squared_error(test_salary, l1_cv_predictions)
# Out:
# 395.4895721068017

# %% [markdown]
# ### Cross validation and tuning a Random Forest model

# %%
# 5 fold cross validation with Random Forest
rf_model = RandomForestRegressor(n_jobs=-1)
cv_rf = cross_val_score(rf_model, train_predictors, train_salary,
                       cv=3, n_jobs=-1)
cv_rf.mean()
# Out:
# 0.6915342437168693

# %%
rf_model
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
# Tuning the Random Forest Model

# Max features
max_features = ['auto', 'log2', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 15, num = 3)]

# Minimum number of samples required to split a node
min_samples_split = [5, 10, 15, 20]

# Minimum number of samples required at each leaf node
min_samples_leaf = [5, 10, 15, 20]

# Create the random grid
random_grid = {
               'max_features': max_features, 
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               }

print(random_grid)
# Out:
# {'max_features': ['auto', 'log2', 'sqrt'], 'max_depth': [5, 10, 15], 'min_samples_split': [5, 10, 15, 20], 'min_samples_leaf': [5, 10, 15, 20]}

# %%
# Random search to tune hyper parameters
rf_model = RandomForestRegressor(random_state=123,
                                n_jobs=-1)

rf_random = RandomizedSearchCV(estimator=rf_model, param_distributions=random_grid,
                              cv=3)

rf_random.fit(train_predictors, train_salary)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomizedSearchCV(cv=3, error_score='raise-deprecating',
#           estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=-1,
#            oob_score=False, random_state=123, verbose=0, warm_start=False),
#           fit_params=None, iid='warn', n_iter=10, n_jobs=None,
#           param_distributions={'max_features': ['auto', 'log2', 'sqrt'], 'max_depth': [5, 10, 15], 'min_samples_split': [5, 10, 15, 20], 'min_samples_leaf': [5, 10, 15, 20]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn', scoring=None, verbose=0)

# %%
rf_random.best_params_
# Out:
# {'min_samples_split': 10,
#  'min_samples_leaf': 15,
#  'max_features': 'sqrt',
#  'max_depth': 15}

# %%
# Best random forest predictions
rf_predictions = rf_random.predict(test_predictors)
mean_squared_error(test_salary, rf_predictions)
# Out:
# 383.6113535198011

# %% [markdown]
# ### XGBoost model

# %%
# xgboost model
dtest = xgb.DMatrix(test_predictors, label=test_salary)
dtrain=xgb.DMatrix(train_predictors, label=train_salary)
num_boost_round=999

max_depths = [i for i in range(3,10,2)]
min_child_weights = [j for j in range(5, 30, 5)]
etas = [0.3, 0.2, 0.1]

# %%
# Grid
max_depth = [i for i in range(3,10,2)]
learning_rate = [0.3, 0.2, 0.1]
min_child_weight = [j for j in range(5,25,5)]
subsample = [0.7, 0.8, 0.9, 1.0]
colsample_bytree = [0.7, 0.8, 0.9, 1.0]


param_grid = {
    "max_depth": max_depth,
    "learning_rate": learning_rate,
    "min_child_weight": min_child_weight,
    "subsample": subsample,
    "colsample_bytree": colsample_bytree
}

param_grid
# Out:
# {'max_depth': [3, 5, 7, 9],
#  'learning_rate': [0.3, 0.2, 0.1],
#  'min_child_weight': [5, 10, 15, 20],
#  'subsample': [0.7, 0.8, 0.9, 1.0],
#  'colsample_bytree': [0.7, 0.8, 0.9, 1.0]}

# %%
xgb_model = xgb.XGBRegressor(n_estimators = 200, 
                            j_jobs=-1, random_state=123)

# %%
xgb_cv_model = RandomizedSearchCV(xgb_model, param_distributions=param_grid,
                                 cv=3)

xgb_cv_model.fit(train_predictors, train_salary)
# Out:
# [11:27:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:31:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:34:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:38:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:42:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:46:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:49:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:58:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:03:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:08:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:13:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:18:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:26:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:30:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:33:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:40:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:44:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:48:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:53:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:57:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:01:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:05:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:09:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:13:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:18:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:20:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:22:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:25:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RandomizedSearchCV(cv=3, error_score='raise-deprecating',
#           estimator=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0,
#        importance_type='gain', j_jobs=-1, learning_rate=0.1,
#        max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#        n_estimators=200, n_jobs=1, nthread=None, objective='reg:linear',
#        random_state=123, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=None, subsample=1, verbosity=1),
#           fit_params=None, iid='warn', n_iter=10, n_jobs=None,
#           param_distributions={'max_depth': [3, 5, 7, 9], 'learning_rate': [0.3, 0.2, 0.1], 'min_child_weight': [5, 10, 15, 20], 'subsample': [0.7, 0.8, 0.9, 1.0], 'colsample_bytree': [0.7, 0.8, 0.9, 1.0]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn', scoring=None, verbose=0)

# %%
# storing the optimal parameters 
best_params = xgb_cv_model.best_params_

# %%
num_boost_round=200
best_model = xgb.train(best_params,
                 dtrain,
                 num_boost_round=num_boost_round,
                 evals=[(dtest, "Test")], 
                 early_stopping_rounds=5)
# Out:
# [0]	Test-rmse:109.905
# Will train until Test-rmse hasn't improved in 5 rounds.
# [1]	Test-rmse:99.5589
# [2]	Test-rmse:90.2662
# [3]	Test-rmse:81.8888
# [4]	Test-rmse:74.4718
# [5]	Test-rmse:67.8095
# [6]	Test-rmse:61.9257
# [7]	Test-rmse:56.6014
# [8]	Test-rmse:51.8196
# [9]	Test-rmse:47.6121
# [10]	Test-rmse:43.9086
# [11]	Test-rmse:40.5824
# [12]	Test-rmse:37.6549
# [13]	Test-rmse:35.1156
# [14]	Test-rmse:32.8868
# [15]	Test-rmse:30.9473
# [16]	Test-rmse:29.2602
# [17]	Test-rmse:27.8077
# [18]	Test-rmse:26.5403
# [19]	Test-rmse:25.4571
# [20]	Test-rmse:24.5152
# [21]	Test-rmse:23.7277
# [22]	Test-rmse:23.0634
# [23]	Test-rmse:22.4555
# [24]	Test-rmse:21.956
# [25]	Test-rmse:21.5319
# [26]	Test-rmse:21.1552
# [27]	Test-rmse:20.8447
# [28]	Test-rmse:20.5841
# [29]	Test-rmse:20.3632
# [30]	Test-rmse:20.1681
# [31]	Test-rmse:20.0061
# [32]	Test-rmse:19.8621
# [33]	Test-rmse:19.7422
# [34]	Test-rmse:19.6372
# [35]	Test-rmse:19.5494
# [36]	Test-rmse:19.4773
# [37]	Test-rmse:19.4125
# [38]	Test-rmse:19.3505
# [39]	Test-rmse:19.2985
# [40]	Test-rmse:19.2433
# [41]	Test-rmse:19.2021
# [42]	Test-rmse:19.1663
# [43]	Test-rmse:19.1286
# [44]	Test-rmse:19.1002
# [45]	Test-rmse:19.0736
# [46]	Test-rmse:19.0476
# [47]	Test-rmse:19.0239
# [48]	Test-rmse:19.0027
# [49]	Test-rmse:18.985
# [50]	Test-rmse:18.9607
# [51]	Test-rmse:18.9395
# [52]	Test-rmse:18.9272
# [53]	Test-rmse:18.9158
# [54]	Test-rmse:18.9039
# [55]	Test-rmse:18.8944
# [56]	Test-rmse:18.8796
# [57]	Test-rmse:18.87
# [58]	Test-rmse:18.86
# [59]	Test-rmse:18.8517
# [60]	Test-rmse:18.8433
# [61]	Test-rmse:18.8369
# [62]	Test-rmse:18.8275
# [63]	Test-rmse:18.8184
# [64]	Test-rmse:18.8125
# [65]	Test-rmse:18.8062
# [66]	Test-rmse:18.7994
# [67]	Test-rmse:18.7939
# [68]	Test-rmse:18.7877
# [69]	Test-rmse:18.7836
# [70]	Test-rmse:18.7789
# [71]	Test-rmse:18.775
# [72]	Test-rmse:18.7705
# [73]	Test-rmse:18.7658
# [74]	Test-rmse:18.7637
# [75]	Test-rmse:18.7599
# [76]	Test-rmse:18.7556
# [77]	Test-rmse:18.7533
# [78]	Test-rmse:18.7511
# [79]	Test-rmse:18.7495
# [80]	Test-rmse:18.7452
# [81]	Test-rmse:18.7427
# [82]	Test-rmse:18.7393
# [83]	Test-rmse:18.7371
# [84]	Test-rmse:18.732
# [85]	Test-rmse:18.7286
# [86]	Test-rmse:18.727
# [87]	Test-rmse:18.7249
# [88]	Test-rmse:18.7237
# [89]	Test-rmse:18.7225
# [90]	Test-rmse:18.7213
# [91]	Test-rmse:18.7191
# [92]	Test-rmse:18.7173
# [93]	Test-rmse:18.7164
# [94]	Test-rmse:18.715
# [95]	Test-rmse:18.7145
# [96]	Test-rmse:18.7131
# [97]	Test-rmse:18.7119
# [98]	Test-rmse:18.7114
# [99]	Test-rmse:18.7103
# [100]	Test-rmse:18.7096
# [101]	Test-rmse:18.7088
# [102]	Test-rmse:18.7069
# [103]	Test-rmse:18.7061
# [104]	Test-rmse:18.7049
# [105]	Test-rmse:18.7035
# [106]	Test-rmse:18.7026
# [107]	Test-rmse:18.7018
# [108]	Test-rmse:18.7014
# [109]	Test-rmse:18.7008
# [110]	Test-rmse:18.7002
# [111]	Test-rmse:18.6999
# [112]	Test-rmse:18.6989
# [113]	Test-rmse:18.6987
# [114]	Test-rmse:18.6978
# [115]	Test-rmse:18.6967
# [116]	Test-rmse:18.6964
# [117]	Test-rmse:18.6963
# [118]	Test-rmse:18.6953
# [119]	Test-rmse:18.6948
# [120]	Test-rmse:18.6949
# [121]	Test-rmse:18.6947
# [122]	Test-rmse:18.6942
# [123]	Test-rmse:18.694
# [124]	Test-rmse:18.6939
# [125]	Test-rmse:18.6938
# [126]	Test-rmse:18.6934
# [127]	Test-rmse:18.6929
# [128]	Test-rmse:18.6926
# [129]	Test-rmse:18.6929
# [130]	Test-rmse:18.6927
# [131]	Test-rmse:18.6924
# [132]	Test-rmse:18.692
# [133]	Test-rmse:18.6917
# [134]	Test-rmse:18.6917
# [135]	Test-rmse:18.6914
# [136]	Test-rmse:18.691
# [137]	Test-rmse:18.6909
# [138]	Test-rmse:18.691
# [139]	Test-rmse:18.6911
# [140]	Test-rmse:18.691
# [141]	Test-rmse:18.6911
# [142]	Test-rmse:18.691
# Stopping. Best iteration:
# [137]	Test-rmse:18.6909

# %%
predictions = best_model.predict(dtest)
mean_squared_error(test_salary, predictions)
# Out:
# 349.3825454069813

# %% [markdown]
# ### ---- 10 Select best model  ----

# %% [markdown]
# ## Part 4 - DEPLOY

# %% [markdown]
# ### ---- 11 Automate pipeline ----

# %%
# load the data into a Pandas dataframe
Test_Features = pd.read_csv('/Users/raviswanath/Dropbox/data/test_features.csv')
Train_Features = pd.read_csv('/Users/raviswanath/Dropbox/data/train_features.csv')
Train_Salaries = pd.read_csv('/Users/raviswanath/Dropbox/data/train_salaries.csv')

Training_data = Train_Features.merge(Train_Salaries, on="jobId")

# %%
# remove extremes
Training_data = remove_extremes(Training_data, 1)
Train_Salaries = Training_data['salary']
Training_data.drop('salary', axis=1, inplace=True)
Train_Features = Training_data
# Out:
# 2465

# %%
# creating a validation set to help tune to boosting model
Train_Features, Valid_Features, Train_Salaries, Valid_Salaries = train_test_split(Train_Features,
                                                                                  Train_Salaries,
                                                                                 test_size=0.3)

# %%
# Select categorical columns and check their cardinality
categorical_cols = [cols for cols in Train_Features.columns 
                   if Train_Features[cols].dtype == 'object']

# only keep columns which have a cardinality < 10
categorical_cols = [col for col in categorical_cols 
                   if Train_Features[col].nunique() <= 10]

# numerical cols
numeric_cols = [col for col in Train_Features.columns
               if Train_Features[col].dtype in ["int64", "float64"]]

# removing high cardinal features from training and validation sets
all_cols = numeric_cols + categorical_cols
Train_Features = Train_Features[all_cols]
Valid_Features = Valid_Features[all_cols]

# %%
# There is no missing data, however, we define imputers to make the code production ready

numerical_transformer = SimpleImputer(strategy='median')

categorical_transformer_jobtype = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='constant', fill_value='SENIOR')),
    ('encdoer', OneHotEncoder(handle_unknown='ignore', sparse=False))
])


categorical_transformer_industry = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='constant', fill_value='WEB')),
    ('encoder', OneHotEncoder(handle_unknown='ignore', sparse=False))
])

categorical_transformer_others = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='constant', fill_value='NONE')),
    ('encoder', OneHotEncoder(handle_unknown='ignore', sparse=False))
])


# Bundle the pre-processing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numeric_cols),
        ('cat1', categorical_transformer_jobtype, ['jobType']),
        ('cat2', categorical_transformer_industry, ['industry']),
        ('cat3', categorical_transformer_others, ['degree', 'major'])
    ])

# %%
# Model pipeline

model_pipeline = Pipeline(steps=[
    ('preprocessing', preprocessor),
    ('model', xgb.XGBRegressor(n_jobs=-1, n_estimators=200))
])

param = {
    'model__max_depth':[i for i in range(3,10,2)],
    'model__learning_rate':[3e-1, 2e-1, 1e-1],
    'model__min_child_weight':[j for j in range(5,25,5)],
    'model__colsample_bytree': [7e-1, 8e-1, 9e-1]
}

fit_params = {
    "model__early_stopping_rounds":5,
    "model__eval_metric": 'rmse',
    "model__eval_set": [(preprocessor.fit_transform(Valid_Features), 
                         Valid_Salaries)]
}

# %%
grid_model = RandomizedSearchCV(model_pipeline,
                          param_distributions=param, cv=3,
                          fit_params=fit_params).fit(Train_Features, Train_Salaries)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:643: DeprecationWarning: "fit_params" as a constructor argument was deprecated in version 0.19 and will be removed in version 0.21. Pass fit parameters to the "fit" method instead.
#   '"fit" method instead.', DeprecationWarning)
# /anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:32:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:87.0503
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:63.646
# [2]	validation_0-rmse:47.8
# [3]	validation_0-rmse:37.6093
# [4]	validation_0-rmse:30.5438
# [5]	validation_0-rmse:25.9598
# [6]	validation_0-rmse:23.4376
# [7]	validation_0-rmse:22.0311
# [8]	validation_0-rmse:20.8979
# [9]	validation_0-rmse:20.2958
# [10]	validation_0-rmse:19.9751
# [11]	validation_0-rmse:19.7387
# [12]	validation_0-rmse:19.5703
# [13]	validation_0-rmse:19.4179
# [14]	validation_0-rmse:19.3405
# [15]	validation_0-rmse:19.2775
# [16]	validation_0-rmse:19.2093
# [17]	validation_0-rmse:19.176
# [18]	validation_0-rmse:19.129
# [19]	validation_0-rmse:19.1053
# [20]	validation_0-rmse:19.0779
# [21]	validation_0-rmse:19.0604
# [22]	validation_0-rmse:19.0416
# [23]	validation_0-rmse:19.0329
# [24]	validation_0-rmse:19.02
# [25]	validation_0-rmse:19.0106
# [26]	validation_0-rmse:19.0058
# [27]	validation_0-rmse:18.9988
# [28]	validation_0-rmse:18.9966
# [29]	validation_0-rmse:18.9901
# [46]	validation_0-rmse:18.9536
# [47]	validation_0-rmse:18.9524
# [48]	validation_0-rmse:18.9514
# [49]	validation_0-rmse:18.9485
# [50]	validation_0-rmse:18.9466
# [51]	validation_0-rmse:18.9461
# [52]	validation_0-rmse:18.9448
# [53]	validation_0-rmse:18.9447
# [54]	validation_0-rmse:18.944
# [55]	validation_0-rmse:18.9424
# [56]	validation_0-rmse:18.9406
# [57]	validation_0-rmse:18.9399
# [58]	validation_0-rmse:18.9393
# [59]	validation_0-rmse:18.9378
# [60]	validation_0-rmse:18.9374
# [61]	validation_0-rmse:18.9378
# [62]	validation_0-rmse:18.9371
# [63]	validation_0-rmse:18.9359
# [64]	validation_0-rmse:18.9335
# [65]	validation_0-rmse:18.9316
# [66]	validation_0-rmse:18.9309
# [67]	validation_0-rmse:18.9307
# [68]	validation_0-rmse:18.9306
# [69]	validation_0-rmse:18.9305
# [70]	validation_0-rmse:18.9299
# [71]	validation_0-rmse:18.9298
# [72]	validation_0-rmse:18.9298
# [73]	validation_0-rmse:18.9294
# [74]	validation_0-rmse:18.9283
# [75]	validation_0-rmse:18.9283
# [76]	validation_0-rmse:18.9287
# [77]	validation_0-rmse:18.9283
# [78]	validation_0-rmse:18.9291
# [79]	validation_0-rmse:18.929
# [80]	validation_0-rmse:18.9292
# Stopping. Best iteration:
# [75]	validation_0-rmse:18.9283
# /anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:49:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:98.5446
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:80.2543
# [2]	validation_0-rmse:65.8746
# [3]	validation_0-rmse:54.6777
# [4]	validation_0-rmse:45.6638
# [5]	validation_0-rmse:38.7517
# [6]	validation_0-rmse:33.5353
# [7]	validation_0-rmse:29.6308
# [8]	validation_0-rmse:26.6988
# [9]	validation_0-rmse:24.6177
# [10]	validation_0-rmse:23.0893
# [11]	validation_0-rmse:22.0477
# [12]	validation_0-rmse:21.26
# [13]	validation_0-rmse:20.6698
# [14]	validation_0-rmse:20.2858
# [15]	validation_0-rmse:19.9947
# [16]	validation_0-rmse:19.7837
# [17]	validation_0-rmse:19.6151
# [18]	validation_0-rmse:19.4843
# [19]	validation_0-rmse:19.4012
# [20]	validation_0-rmse:19.3297
# [21]	validation_0-rmse:19.2648
# [22]	validation_0-rmse:19.2063
# [23]	validation_0-rmse:19.1653
# [24]	validation_0-rmse:19.13
# [25]	validation_0-rmse:19.108
# [26]	validation_0-rmse:19.0852
# [27]	validation_0-rmse:19.0628
# [28]	validation_0-rmse:19.0506
# [29]	validation_0-rmse:19.0346
# [30]	validation_0-rmse:19.0257
# [31]	validation_0-rmse:19.0177
# [32]	validation_0-rmse:19.0112
# [33]	validation_0-rmse:19.0044
# [34]	validation_0-rmse:18.9974
# [35]	validation_0-rmse:18.9923
# [36]	validation_0-rmse:18.9865
# [37]	validation_0-rmse:18.9833
# [38]	validation_0-rmse:18.9724
# [39]	validation_0-rmse:18.971
# [40]	validation_0-rmse:18.9683
# [41]	validation_0-rmse:18.9609
# [42]	validation_0-rmse:18.9565
# [43]	validation_0-rmse:18.9552
# [44]	validation_0-rmse:18.954
# [45]	validation_0-rmse:18.9534
# [39]	validation_0-rmse:18.9221
# [40]	validation_0-rmse:18.9206
# [41]	validation_0-rmse:18.9188
# [42]	validation_0-rmse:18.9194
# [43]	validation_0-rmse:18.9183
# [44]	validation_0-rmse:18.9177
# [45]	validation_0-rmse:18.9183
# [46]	validation_0-rmse:18.9188
# [47]	validation_0-rmse:18.9187
# [48]	validation_0-rmse:18.9194
# [49]	validation_0-rmse:18.9198
# Stopping. Best iteration:
# [44]	validation_0-rmse:18.9177
# /anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:55:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:98.4135
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:80.2411
# [2]	validation_0-rmse:65.8303
# [3]	validation_0-rmse:54.6925
# [4]	validation_0-rmse:45.6784
# [5]	validation_0-rmse:38.5772
# [6]	validation_0-rmse:33.3399
# [7]	validation_0-rmse:29.5595
# [8]	validation_0-rmse:26.4652
# [9]	validation_0-rmse:24.2514
# [10]	validation_0-rmse:22.7554
# [11]	validation_0-rmse:21.6278
# [12]	validation_0-rmse:20.8518
# [13]	validation_0-rmse:20.3212
# [14]	validation_0-rmse:19.9442
# [15]	validation_0-rmse:19.6894
# [16]	validation_0-rmse:19.4964
# [17]	validation_0-rmse:19.361
# [18]	validation_0-rmse:19.2671
# [19]	validation_0-rmse:19.1966
# [20]	validation_0-rmse:19.1413
# [21]	validation_0-rmse:19.106
# [22]	validation_0-rmse:19.0703
# [23]	validation_0-rmse:19.0438
# [24]	validation_0-rmse:19.0201
# [25]	validation_0-rmse:19.0045
# [26]	validation_0-rmse:18.9918
# [27]	validation_0-rmse:18.9824
# [28]	validation_0-rmse:18.974
# [29]	validation_0-rmse:18.9662
# [30]	validation_0-rmse:18.9599
# [31]	validation_0-rmse:18.9563
# [32]	validation_0-rmse:18.9524
# [33]	validation_0-rmse:18.9483
# [34]	validation_0-rmse:18.9388
# [35]	validation_0-rmse:18.9363
# [36]	validation_0-rmse:18.9345
# [37]	validation_0-rmse:18.9321
# [38]	validation_0-rmse:18.9305
# [39]	validation_0-rmse:18.9292
# [40]	validation_0-rmse:18.9269
# [41]	validation_0-rmse:18.9262
# [42]	validation_0-rmse:18.9257
# [43]	validation_0-rmse:18.9224
# [44]	validation_0-rmse:18.9214
# [45]	validation_0-rmse:18.9214
# [46]	validation_0-rmse:18.9218
# [47]	validation_0-rmse:18.9218
# [48]	validation_0-rmse:18.9225
# [49]	validation_0-rmse:18.9224
# [50]	validation_0-rmse:18.9228
# Stopping. Best iteration:
# [45]	validation_0-rmse:18.9214
# /anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:56:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:98.4099
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:80.2363
# [2]	validation_0-rmse:65.8317
# [3]	validation_0-rmse:54.6953
# [4]	validation_0-rmse:45.6889
# [5]	validation_0-rmse:38.5889
# [6]	validation_0-rmse:33.3458
# [7]	validation_0-rmse:29.5663
# [8]	validation_0-rmse:26.4605
# [9]	validation_0-rmse:24.2429
# [10]	validation_0-rmse:22.7428
# [11]	validation_0-rmse:21.6156
# [12]	validation_0-rmse:20.8427
# [13]	validation_0-rmse:20.315
# [14]	validation_0-rmse:19.941
# [15]	validation_0-rmse:19.6843
# [16]	validation_0-rmse:19.4913
# [17]	validation_0-rmse:19.3552
# [18]	validation_0-rmse:19.2613
# [19]	validation_0-rmse:19.1914
# [20]	validation_0-rmse:19.1317
# [21]	validation_0-rmse:19.0957
# [22]	validation_0-rmse:19.057
# [23]	validation_0-rmse:19.0323
# [24]	validation_0-rmse:19.0114
# [25]	validation_0-rmse:18.9977
# [26]	validation_0-rmse:18.9869
# [27]	validation_0-rmse:18.9776
# [28]	validation_0-rmse:18.9662
# [29]	validation_0-rmse:18.9571
# [30]	validation_0-rmse:18.9507
# [31]	validation_0-rmse:18.9454
# [32]	validation_0-rmse:18.9397
# [33]	validation_0-rmse:18.9354
# [34]	validation_0-rmse:18.9252
# [35]	validation_0-rmse:18.9229
# [36]	validation_0-rmse:18.921
# [37]	validation_0-rmse:18.9187
# [38]	validation_0-rmse:18.9154
# [39]	validation_0-rmse:18.9156
# [40]	validation_0-rmse:18.914
# [41]	validation_0-rmse:18.9131
# [42]	validation_0-rmse:18.9128
# [43]	validation_0-rmse:18.9127
# [44]	validation_0-rmse:18.9113
# [45]	validation_0-rmse:18.9108
# [46]	validation_0-rmse:18.9111
# [47]	validation_0-rmse:18.9114
# [48]	validation_0-rmse:18.9124
# [49]	validation_0-rmse:18.9125
# [50]	validation_0-rmse:18.911
# Stopping. Best iteration:
# [45]	validation_0-rmse:18.9108
# /anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:58:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:98.7493
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:80.7795
# [2]	validation_0-rmse:66.6826
# [3]	validation_0-rmse:55.6467
# [4]	validation_0-rmse:46.8791
# [5]	validation_0-rmse:40.0141
# [6]	validation_0-rmse:34.9563
# [7]	validation_0-rmse:31.1619
# [8]	validation_0-rmse:28.1865
# [9]	validation_0-rmse:26.0622
# [10]	validation_0-rmse:24.5157
# [11]	validation_0-rmse:23.3749
# [12]	validation_0-rmse:22.521
# [13]	validation_0-rmse:21.8979
# [14]	validation_0-rmse:21.4256
# [15]	validation_0-rmse:21.0377
# [16]	validation_0-rmse:20.7497
# [17]	validation_0-rmse:20.4993
# [18]	validation_0-rmse:20.3131
# [19]	validation_0-rmse:20.1536
# [20]	validation_0-rmse:20.0077
# [21]	validation_0-rmse:19.8867
# [22]	validation_0-rmse:19.7688
# [23]	validation_0-rmse:19.6692
# [24]	validation_0-rmse:19.5983
# [25]	validation_0-rmse:19.5321
# [26]	validation_0-rmse:19.4752
# [27]	validation_0-rmse:19.4276
# [28]	validation_0-rmse:19.3829
# [29]	validation_0-rmse:19.347
# [30]	validation_0-rmse:19.3067
# [31]	validation_0-rmse:19.279
# [32]	validation_0-rmse:19.2517
# [33]	validation_0-rmse:19.2295
# [34]	validation_0-rmse:19.2068
# [35]	validation_0-rmse:19.1851
# [36]	validation_0-rmse:19.1655
# [37]	validation_0-rmse:19.15
# [38]	validation_0-rmse:19.1382
# [39]	validation_0-rmse:19.1086
# [40]	validation_0-rmse:19.0975
# [41]	validation_0-rmse:19.0813
# [42]	validation_0-rmse:19.0741
# [43]	validation_0-rmse:19.0602
# [44]	validation_0-rmse:19.0539
# [45]	validation_0-rmse:19.0479
# [46]	validation_0-rmse:19.0324
# [34]	validation_0-rmse:19.2147
# [35]	validation_0-rmse:19.1992
# [36]	validation_0-rmse:19.1842
# [37]	validation_0-rmse:19.1702
# [38]	validation_0-rmse:19.153
# [39]	validation_0-rmse:19.1349
# [40]	validation_0-rmse:19.1214
# [41]	validation_0-rmse:19.1102
# [42]	validation_0-rmse:19.1028
# [43]	validation_0-rmse:19.0933
# [44]	validation_0-rmse:19.0756
# [45]	validation_0-rmse:19.0699
# [46]	validation_0-rmse:19.0547
# [47]	validation_0-rmse:19.0489
# [48]	validation_0-rmse:19.0443
# [49]	validation_0-rmse:19.0395
# [50]	validation_0-rmse:19.0237
# [51]	validation_0-rmse:19.0196
# [52]	validation_0-rmse:19.0133
# [53]	validation_0-rmse:19.0112
# [54]	validation_0-rmse:19.0076
# [55]	validation_0-rmse:18.9902
# [56]	validation_0-rmse:18.9847
# [57]	validation_0-rmse:18.9785
# [58]	validation_0-rmse:18.9756
# [59]	validation_0-rmse:18.9741
# [60]	validation_0-rmse:18.9712
# [61]	validation_0-rmse:18.9676
# [62]	validation_0-rmse:18.9664
# [63]	validation_0-rmse:18.9616
# [64]	validation_0-rmse:18.9591
# [65]	validation_0-rmse:18.956
# [66]	validation_0-rmse:18.9538
# [67]	validation_0-rmse:18.9529
# [68]	validation_0-rmse:18.9512
# [69]	validation_0-rmse:18.9461
# [70]	validation_0-rmse:18.9425
# [71]	validation_0-rmse:18.9419
# [72]	validation_0-rmse:18.9401
# [73]	validation_0-rmse:18.9385
# [74]	validation_0-rmse:18.9381
# [75]	validation_0-rmse:18.9373
# [76]	validation_0-rmse:18.9355
# [77]	validation_0-rmse:18.9342
# [78]	validation_0-rmse:18.9306
# [79]	validation_0-rmse:18.9286
# [80]	validation_0-rmse:18.9279
# [81]	validation_0-rmse:18.9262
# [82]	validation_0-rmse:18.9254
# [83]	validation_0-rmse:18.9244
# [84]	validation_0-rmse:18.9237
# [85]	validation_0-rmse:18.9225
# [86]	validation_0-rmse:18.9215
# [87]	validation_0-rmse:18.9206
# [88]	validation_0-rmse:18.9199
# [89]	validation_0-rmse:18.9194
# [90]	validation_0-rmse:18.9188
# [91]	validation_0-rmse:18.9163
# [92]	validation_0-rmse:18.9153
# [93]	validation_0-rmse:18.9153
# [94]	validation_0-rmse:18.9127
# [95]	validation_0-rmse:18.9116
# [96]	validation_0-rmse:18.9113
# [97]	validation_0-rmse:18.9103
# [98]	validation_0-rmse:18.9098
# [99]	validation_0-rmse:18.9081
# [100]	validation_0-rmse:18.9081
# [101]	validation_0-rmse:18.908
# [102]	validation_0-rmse:18.9078
# [103]	validation_0-rmse:18.9079
# [104]	validation_0-rmse:18.9074
# [105]	validation_0-rmse:18.9069
# [106]	validation_0-rmse:18.9057
# [107]	validation_0-rmse:18.9049
# [108]	validation_0-rmse:18.9035
# [109]	validation_0-rmse:18.903
# [110]	validation_0-rmse:18.9024
# [111]	validation_0-rmse:18.9019
# [112]	validation_0-rmse:18.9017
# [113]	validation_0-rmse:18.901
# /anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [19:05:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:98.7429
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:80.7703
# [2]	validation_0-rmse:66.6648
# [3]	validation_0-rmse:55.6278
# [4]	validation_0-rmse:46.8726
# [5]	validation_0-rmse:40.0429
# [6]	validation_0-rmse:34.9965
# [7]	validation_0-rmse:31.2516
# [8]	validation_0-rmse:28.2841
# [9]	validation_0-rmse:26.0859
# [10]	validation_0-rmse:24.528
# [11]	validation_0-rmse:23.3865
# [12]	validation_0-rmse:22.5289
# [13]	validation_0-rmse:21.9058
# [14]	validation_0-rmse:21.429
# [15]	validation_0-rmse:21.0229
# [16]	validation_0-rmse:20.7256
# [17]	validation_0-rmse:20.495
# [18]	validation_0-rmse:20.3104
# [19]	validation_0-rmse:20.1362
# [20]	validation_0-rmse:20.0021
# [21]	validation_0-rmse:19.9066
# [22]	validation_0-rmse:19.7825
# [23]	validation_0-rmse:19.695
# [24]	validation_0-rmse:19.6031
# [25]	validation_0-rmse:19.5473
# [26]	validation_0-rmse:19.4937
# [27]	validation_0-rmse:19.4482
# [28]	validation_0-rmse:19.3896
# [29]	validation_0-rmse:19.3521
# [30]	validation_0-rmse:19.3101
# [31]	validation_0-rmse:19.2661
# [32]	validation_0-rmse:19.24
# [33]	validation_0-rmse:19.2113
# [34]	validation_0-rmse:19.1916
# [35]	validation_0-rmse:19.1752
# [36]	validation_0-rmse:19.1606
# [37]	validation_0-rmse:19.1478
# [38]	validation_0-rmse:19.1373
# [39]	validation_0-rmse:19.1251
# [40]	validation_0-rmse:19.111
# [41]	validation_0-rmse:19.0956
# [42]	validation_0-rmse:19.0863
# [43]	validation_0-rmse:19.0768
# [44]	validation_0-rmse:19.0666
# [45]	validation_0-rmse:19.0594
# [46]	validation_0-rmse:19.0502
# [47]	validation_0-rmse:19.0441
# [48]	validation_0-rmse:19.0353
# [49]	validation_0-rmse:19.0296
# [50]	validation_0-rmse:19.0245
# [51]	validation_0-rmse:19.0044
# [52]	validation_0-rmse:19.001
# [53]	validation_0-rmse:18.9953
# [54]	validation_0-rmse:18.9909
# [55]	validation_0-rmse:18.9888
# [56]	validation_0-rmse:18.9851
# [57]	validation_0-rmse:18.9821
# [58]	validation_0-rmse:18.9765
# [59]	validation_0-rmse:18.9742
# [60]	validation_0-rmse:18.9709
# [61]	validation_0-rmse:18.9683
# [62]	validation_0-rmse:18.9661
# [63]	validation_0-rmse:18.9639
# [64]	validation_0-rmse:18.9578
# [65]	validation_0-rmse:18.9571
# [66]	validation_0-rmse:18.956
# [67]	validation_0-rmse:18.9539
# [68]	validation_0-rmse:18.9519
# [69]	validation_0-rmse:18.9506
# [70]	validation_0-rmse:18.9452
# [71]	validation_0-rmse:18.9431
# [72]	validation_0-rmse:18.9427
# [73]	validation_0-rmse:18.9406
# [74]	validation_0-rmse:18.9393
# [75]	validation_0-rmse:18.938
# [76]	validation_0-rmse:18.9372
# [77]	validation_0-rmse:18.9369
# [78]	validation_0-rmse:18.9301
# [79]	validation_0-rmse:18.9289
# [80]	validation_0-rmse:18.9272
# [81]	validation_0-rmse:18.9251
# [82]	validation_0-rmse:18.9235
# [83]	validation_0-rmse:18.9225
# [84]	validation_0-rmse:18.9219
# [85]	validation_0-rmse:18.92
# [86]	validation_0-rmse:18.9191
# [87]	validation_0-rmse:18.9188
# [88]	validation_0-rmse:18.9173
# [89]	validation_0-rmse:18.9156
# [90]	validation_0-rmse:18.9146
# [91]	validation_0-rmse:18.9136
# [92]	validation_0-rmse:18.9127
# [93]	validation_0-rmse:18.9122
# [94]	validation_0-rmse:18.9109
# [95]	validation_0-rmse:18.9105
# [96]	validation_0-rmse:18.9103
# [97]	validation_0-rmse:18.9093
# [98]	validation_0-rmse:18.9085
# [99]	validation_0-rmse:18.9078
# [100]	validation_0-rmse:18.9063
# [101]	validation_0-rmse:18.9059
# [102]	validation_0-rmse:18.9055
# [103]	validation_0-rmse:18.905
# [104]	validation_0-rmse:18.9047
# [105]	validation_0-rmse:18.9038
# [106]	validation_0-rmse:18.9031
# [107]	validation_0-rmse:18.9009
# [108]	validation_0-rmse:18.8995
# [109]	validation_0-rmse:18.8991
# [110]	validation_0-rmse:18.8988
# [111]	validation_0-rmse:18.8986
# [112]	validation_0-rmse:18.8983
# [113]	validation_0-rmse:18.8978
# [114]	validation_0-rmse:18.8971
# [115]	validation_0-rmse:18.8966
# [116]	validation_0-rmse:18.8964
# [117]	validation_0-rmse:18.8963
# [118]	validation_0-rmse:18.8944
# [119]	validation_0-rmse:18.8937
# [120]	validation_0-rmse:18.8931
# [121]	validation_0-rmse:18.8923
# [122]	validation_0-rmse:18.8914
# [123]	validation_0-rmse:18.891
# [124]	validation_0-rmse:18.8907
# [125]	validation_0-rmse:18.8898
# [126]	validation_0-rmse:18.8899
# [127]	validation_0-rmse:18.8896
# [128]	validation_0-rmse:18.8896
# [129]	validation_0-rmse:18.8892
# [130]	validation_0-rmse:18.8894
# [131]	validation_0-rmse:18.889
# [132]	validation_0-rmse:18.8889
# [133]	validation_0-rmse:18.8881
# [134]	validation_0-rmse:18.888
# [135]	validation_0-rmse:18.8877
# [136]	validation_0-rmse:18.887
# [137]	validation_0-rmse:18.8865
# [138]	validation_0-rmse:18.8863
# [139]	validation_0-rmse:18.8859
# [140]	validation_0-rmse:18.8857
# [141]	validation_0-rmse:18.8854
# [142]	validation_0-rmse:18.8845
# [143]	validation_0-rmse:18.8842
# [144]	validation_0-rmse:18.8841
# [145]	validation_0-rmse:18.8838
# [146]	validation_0-rmse:18.8834
# [147]	validation_0-rmse:18.8831
# [148]	validation_0-rmse:18.8826
# [149]	validation_0-rmse:18.8825
# [150]	validation_0-rmse:18.8823
# [151]	validation_0-rmse:18.8823
# [152]	validation_0-rmse:18.8818
# [153]	validation_0-rmse:18.8817
# [154]	validation_0-rmse:18.8817
# [155]	validation_0-rmse:18.8814
# [156]	validation_0-rmse:18.8813
# [157]	validation_0-rmse:18.8812
# [158]	validation_0-rmse:18.8812
# [159]	validation_0-rmse:18.8812
# [160]	validation_0-rmse:18.8813
# [161]	validation_0-rmse:18.881
# [162]	validation_0-rmse:18.881
# [163]	validation_0-rmse:18.8808
# [164]	validation_0-rmse:18.8803
# [165]	validation_0-rmse:18.8802
# [166]	validation_0-rmse:18.8802
# [167]	validation_0-rmse:18.8795
# [168]	validation_0-rmse:18.8793
# [169]	validation_0-rmse:18.8795
# [170]	validation_0-rmse:18.8794
# [171]	validation_0-rmse:18.8789
# [172]	validation_0-rmse:18.8788
# [173]	validation_0-rmse:18.8786
# [174]	validation_0-rmse:18.8787
# ...
# [50]	validation_0-rmse:19.1766
# [51]	validation_0-rmse:19.1724
# [52]	validation_0-rmse:19.163
# [53]	validation_0-rmse:19.16
# [54]	validation_0-rmse:19.147
# [55]	validation_0-rmse:19.1425
# [56]	validation_0-rmse:19.1361
# [57]	validation_0-rmse:19.1335
# [58]	validation_0-rmse:19.1263
# [59]	validation_0-rmse:19.1228
# [60]	validation_0-rmse:19.1179
# [61]	validation_0-rmse:19.0997
# [62]	validation_0-rmse:19.0982
# [63]	validation_0-rmse:19.0925
# [64]	validation_0-rmse:19.0827
# [65]	validation_0-rmse:19.0811
# [66]	validation_0-rmse:19.0784
# [67]	validation_0-rmse:19.0755
# [68]	validation_0-rmse:19.0744
# [69]	validation_0-rmse:19.0719
# [70]	validation_0-rmse:19.0698
# [71]	validation_0-rmse:19.0685
# [72]	validation_0-rmse:19.0671
# [73]	validation_0-rmse:19.0638
# [74]	validation_0-rmse:19.0553
# [75]	validation_0-rmse:19.0537
# [76]	validation_0-rmse:19.0495
# [77]	validation_0-rmse:19.04
# [78]	validation_0-rmse:19.0369
# [79]	validation_0-rmse:19.0358
# [80]	validation_0-rmse:19.0278
# [81]	validation_0-rmse:19.0257
# [82]	validation_0-rmse:19.0247
# [83]	validation_0-rmse:19.0233
# [84]	validation_0-rmse:19.0202
# [85]	validation_0-rmse:19.0151
# [86]	validation_0-rmse:19.0143
# [87]	validation_0-rmse:19.0136
# [88]	validation_0-rmse:19.0077
# [89]	validation_0-rmse:19.0071
# [90]	validation_0-rmse:19.0025
# [91]	validation_0-rmse:18.9985
# [92]	validation_0-rmse:18.9969
# [93]	validation_0-rmse:18.9935
# [94]	validation_0-rmse:18.9927
# [95]	validation_0-rmse:18.9887
# [96]	validation_0-rmse:18.9871
# [97]	validation_0-rmse:18.9862
# [98]	validation_0-rmse:18.9827
# [99]	validation_0-rmse:18.97
# [100]	validation_0-rmse:18.9672
# [101]	validation_0-rmse:18.9663
# [102]	validation_0-rmse:18.9626
# [103]	validation_0-rmse:18.9599
# [104]	validation_0-rmse:18.9584
# [105]	validation_0-rmse:18.9575
# [106]	validation_0-rmse:18.9571
# [107]	validation_0-rmse:18.9551
# [108]	validation_0-rmse:18.953
# [109]	validation_0-rmse:18.9506
# [110]	validation_0-rmse:18.9498
# [111]	validation_0-rmse:18.9485
# [112]	validation_0-rmse:18.9474
# /anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [19:48:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:98.4132
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:80.2076
# [2]	validation_0-rmse:65.8115
# [3]	validation_0-rmse:54.5447
# [4]	validation_0-rmse:45.4736
# [5]	validation_0-rmse:38.3744
# [6]	validation_0-rmse:33.1078
# [7]	validation_0-rmse:29.2135
# [8]	validation_0-rmse:26.218
# [9]	validation_0-rmse:24.0346
# [10]	validation_0-rmse:22.5704
# [11]	validation_0-rmse:21.4851
# [12]	validation_0-rmse:20.7348
# [13]	validation_0-rmse:20.2292
# [14]	validation_0-rmse:19.8774
# [15]	validation_0-rmse:19.6233
# [16]	validation_0-rmse:19.4507
# [17]	validation_0-rmse:19.3267
# [18]	validation_0-rmse:19.2203
# [19]	validation_0-rmse:19.158
# [20]	validation_0-rmse:19.1143
# [21]	validation_0-rmse:19.0798
# [22]	validation_0-rmse:19.0512
# [23]	validation_0-rmse:19.0301
# [24]	validation_0-rmse:19.0121
# [25]	validation_0-rmse:18.9994
# [26]	validation_0-rmse:18.9909
# [27]	validation_0-rmse:18.9828
# [28]	validation_0-rmse:18.9686
# [29]	validation_0-rmse:18.9606
# [30]	validation_0-rmse:18.956
# [31]	validation_0-rmse:18.9526
# [32]	validation_0-rmse:18.9514
# [33]	validation_0-rmse:18.9482
# [34]	validation_0-rmse:18.9455
# [35]	validation_0-rmse:18.943
# [36]	validation_0-rmse:18.9397
# [37]	validation_0-rmse:18.9391
# [38]	validation_0-rmse:18.9376
# [39]	validation_0-rmse:18.9386
# [40]	validation_0-rmse:18.9376
# [41]	validation_0-rmse:18.9366
# [42]	validation_0-rmse:18.9371
# [43]	validation_0-rmse:18.9376
# [44]	validation_0-rmse:18.9347
# [45]	validation_0-rmse:18.9356
# [46]	validation_0-rmse:18.9346
# [47]	validation_0-rmse:18.9366
# [48]	validation_0-rmse:18.9382
# [49]	validation_0-rmse:18.9391
# [50]	validation_0-rmse:18.9395
# [51]	validation_0-rmse:18.94
# Stopping. Best iteration:
# [46]	validation_0-rmse:18.9346
# /anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [19:50:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:98.413
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:80.2019
# [2]	validation_0-rmse:65.8052
# [3]	validation_0-rmse:54.5393
# [4]	validation_0-rmse:45.4614
# [5]	validation_0-rmse:38.3608
# [6]	validation_0-rmse:33.0998
# [7]	validation_0-rmse:29.2105
# [8]	validation_0-rmse:26.2071
# [9]	validation_0-rmse:24.0267
# [10]	validation_0-rmse:22.5575
# [11]	validation_0-rmse:21.4786
# [12]	validation_0-rmse:20.7357
# [13]	validation_0-rmse:20.2325
# [14]	validation_0-rmse:19.878
# [15]	validation_0-rmse:19.6229
# [16]	validation_0-rmse:19.449
# [17]	validation_0-rmse:19.328
# [18]	validation_0-rmse:19.2236
# [19]	validation_0-rmse:19.1633
# [20]	validation_0-rmse:19.1128
# [21]	validation_0-rmse:19.0806
# [22]	validation_0-rmse:19.0518
# [23]	validation_0-rmse:19.0304
# [24]	validation_0-rmse:19.0115
# [25]	validation_0-rmse:19.0013
# [26]	validation_0-rmse:18.9918
# [27]	validation_0-rmse:18.9832
# [28]	validation_0-rmse:18.9746
# [29]	validation_0-rmse:18.9684
# [30]	validation_0-rmse:18.9635
# [31]	validation_0-rmse:18.9607
# [32]	validation_0-rmse:18.9571
# [33]	validation_0-rmse:18.9546
# [34]	validation_0-rmse:18.9496
# [35]	validation_0-rmse:18.9466
# [36]	validation_0-rmse:18.9457
# [37]	validation_0-rmse:18.9443
# [38]	validation_0-rmse:18.9424
# [39]	validation_0-rmse:18.9423
# [40]	validation_0-rmse:18.9408
# [41]	validation_0-rmse:18.938
# [42]	validation_0-rmse:18.938
# [43]	validation_0-rmse:18.9384
# [44]	validation_0-rmse:18.935
# [45]	validation_0-rmse:18.9362
# [46]	validation_0-rmse:18.9367
# [47]	validation_0-rmse:18.9365
# [48]	validation_0-rmse:18.9356
# [49]	validation_0-rmse:18.9363
# Stopping. Best iteration:
# [44]	validation_0-rmse:18.935
# /anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [19:52:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:98.4096
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:80.1982
# [2]	validation_0-rmse:65.8014
# [3]	validation_0-rmse:54.5354
# [4]	validation_0-rmse:45.4609
# [5]	validation_0-rmse:38.3665
# [6]	validation_0-rmse:33.0946
# [7]	validation_0-rmse:29.2023
# [8]	validation_0-rmse:26.2022
# [9]	validation_0-rmse:24.0145
# [10]	validation_0-rmse:22.5532
# [11]	validation_0-rmse:21.4722
# [12]	validation_0-rmse:20.7251
# [13]	validation_0-rmse:20.2231
# [14]	validation_0-rmse:19.8715
# [15]	validation_0-rmse:19.6191
# [16]	validation_0-rmse:19.444
# [17]	validation_0-rmse:19.3251
# [18]	validation_0-rmse:19.2213
# [19]	validation_0-rmse:19.1591
# [20]	validation_0-rmse:19.1081
# [21]	validation_0-rmse:19.0751
# [22]	validation_0-rmse:19.0438
# [23]	validation_0-rmse:19.0222
# [24]	validation_0-rmse:19.0039
# [25]	validation_0-rmse:18.99
# [26]	validation_0-rmse:18.9807
# [27]	validation_0-rmse:18.9725
# [28]	validation_0-rmse:18.9606
# [29]	validation_0-rmse:18.9562
# [30]	validation_0-rmse:18.952
# [31]	validation_0-rmse:18.9467
# [32]	validation_0-rmse:18.9439
# [33]	validation_0-rmse:18.9422
# [34]	validation_0-rmse:18.9347
# [35]	validation_0-rmse:18.9333
# [36]	validation_0-rmse:18.9319
# [37]	validation_0-rmse:18.9311
# [38]	validation_0-rmse:18.9297
# [39]	validation_0-rmse:18.9295
# [40]	validation_0-rmse:18.9288
# [41]	validation_0-rmse:18.9267
# [42]	validation_0-rmse:18.9269
# [43]	validation_0-rmse:18.9261
# [44]	validation_0-rmse:18.924
# [45]	validation_0-rmse:18.9248
# [46]	validation_0-rmse:18.9249
# [47]	validation_0-rmse:18.925
# [48]	validation_0-rmse:18.9249
# [49]	validation_0-rmse:18.9258
# Stopping. Best iteration:
# [44]	validation_0-rmse:18.924
# /anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [19:53:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:110.132
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:99.7506
# [2]	validation_0-rmse:90.4767
# [3]	validation_0-rmse:82.1916
# [4]	validation_0-rmse:74.6562
# [5]	validation_0-rmse:67.9342
# [6]	validation_0-rmse:61.9492
# [7]	validation_0-rmse:56.6234
# [8]	validation_0-rmse:51.8572
# [9]	validation_0-rmse:47.637
# [10]	validation_0-rmse:43.9129
# [11]	validation_0-rmse:40.6416
# [12]	validation_0-rmse:37.7475
# [13]	validation_0-rmse:35.188
# [14]	validation_0-rmse:32.9634
# [15]	validation_0-rmse:31.017
# [16]	validation_0-rmse:29.313
# [17]	validation_0-rmse:27.846
# [18]	validation_0-rmse:26.5845
# [19]	validation_0-rmse:25.5029
# [20]	validation_0-rmse:24.5822
# [21]	validation_0-rmse:23.7997
# [22]	validation_0-rmse:23.085
# [23]	validation_0-rmse:22.5055
# [24]	validation_0-rmse:22.0008
# [25]	validation_0-rmse:21.5716
# [26]	validation_0-rmse:21.2207
# [27]	validation_0-rmse:20.9162
# [28]	validation_0-rmse:20.6668
# [29]	validation_0-rmse:20.4456
# [30]	validation_0-rmse:20.2511
# [31]	validation_0-rmse:20.093
# [32]	validation_0-rmse:19.9564
# [33]	validation_0-rmse:19.836
# [34]	validation_0-rmse:19.7374
# [35]	validation_0-rmse:19.6484
# [36]	validation_0-rmse:19.5707
# [37]	validation_0-rmse:19.5001
# [38]	validation_0-rmse:19.4462
# [39]	validation_0-rmse:19.3973
# [40]	validation_0-rmse:19.3519
# [41]	validation_0-rmse:19.3099
# [42]	validation_0-rmse:19.2743
# [43]	validation_0-rmse:19.2451
# [44]	validation_0-rmse:19.2156
# [45]	validation_0-rmse:19.1918
# [46]	validation_0-rmse:19.1664
# [47]	validation_0-rmse:19.1405
# [48]	validation_0-rmse:19.1242
# [49]	validation_0-rmse:19.1015
# [50]	validation_0-rmse:19.0855
# [51]	validation_0-rmse:19.0714
# [52]	validation_0-rmse:19.0566
# [53]	validation_0-rmse:19.0452
# [54]	validation_0-rmse:19.0332
# [55]	validation_0-rmse:19.0231
# [56]	validation_0-rmse:19.0151
# [57]	validation_0-rmse:19.0073
# [58]	validation_0-rmse:18.9976
# [59]	validation_0-rmse:18.9913
# [60]	validation_0-rmse:18.9845
# [61]	validation_0-rmse:18.9693
# [62]	validation_0-rmse:18.9646
# [63]	validation_0-rmse:18.9607
# [64]	validation_0-rmse:18.9551
# [65]	validation_0-rmse:18.9499
# [66]	validation_0-rmse:18.9473
# [67]	validation_0-rmse:18.9391
# [68]	validation_0-rmse:18.9348
# [69]	validation_0-rmse:18.9317
# [70]	validation_0-rmse:18.9255
# [71]	validation_0-rmse:18.9231
# [72]	validation_0-rmse:18.9207
# [73]	validation_0-rmse:18.9179
# [74]	validation_0-rmse:18.9158
# [75]	validation_0-rmse:18.9082
# [76]	validation_0-rmse:18.9051
# [77]	validation_0-rmse:18.9019
# [78]	validation_0-rmse:18.9
# [79]	validation_0-rmse:18.898
# [80]	validation_0-rmse:18.8947
# [81]	validation_0-rmse:18.8927
# [82]	validation_0-rmse:18.8893
# [83]	validation_0-rmse:18.8877
# [84]	validation_0-rmse:18.8865
# [85]	validation_0-rmse:18.8851
# [86]	validation_0-rmse:18.8838
# [87]	validation_0-rmse:18.8815
# [88]	validation_0-rmse:18.8807
# [89]	validation_0-rmse:18.8775
# [90]	validation_0-rmse:18.8769
# [91]	validation_0-rmse:18.8761
# [92]	validation_0-rmse:18.8755
# [93]	validation_0-rmse:18.8749
# [94]	validation_0-rmse:18.8739
# [95]	validation_0-rmse:18.873
# [96]	validation_0-rmse:18.8721
# [97]	validation_0-rmse:18.8716
# [98]	validation_0-rmse:18.8709
# [99]	validation_0-rmse:18.8694
# [100]	validation_0-rmse:18.8686
# [101]	validation_0-rmse:18.8674
# [102]	validation_0-rmse:18.8664
# [103]	validation_0-rmse:18.8659
# [104]	validation_0-rmse:18.8654
# [105]	validation_0-rmse:18.865
# [106]	validation_0-rmse:18.8646
# [107]	validation_0-rmse:18.8645
# [108]	validation_0-rmse:18.864
# [109]	validation_0-rmse:18.8636
# [110]	validation_0-rmse:18.8638
# [111]	validation_0-rmse:18.8635
# [112]	validation_0-rmse:18.8631
# [113]	validation_0-rmse:18.8626
# [114]	validation_0-rmse:18.862
# [115]	validation_0-rmse:18.8616
# [116]	validation_0-rmse:18.8618
# [117]	validation_0-rmse:18.8616
# [118]	validation_0-rmse:18.8609
# [119]	validation_0-rmse:18.8606
# [120]	validation_0-rmse:18.8601
# [121]	validation_0-rmse:18.8592
# [122]	validation_0-rmse:18.8588
# [123]	validation_0-rmse:18.8584
# [124]	validation_0-rmse:18.8584
# [125]	validation_0-rmse:18.8583
# [126]	validation_0-rmse:18.8579
# [127]	validation_0-rmse:18.8579
# [128]	validation_0-rmse:18.8581
# [129]	validation_0-rmse:18.8575
# [130]	validation_0-rmse:18.8574
# [131]	validation_0-rmse:18.8572
# [132]	validation_0-rmse:18.8572
# [133]	validation_0-rmse:18.8573
# [134]	validation_0-rmse:18.8573
# [135]	validation_0-rmse:18.8573
# [136]	validation_0-rmse:18.8571
# [137]	validation_0-rmse:18.8572
# [138]	validation_0-rmse:18.8573
# [139]	validation_0-rmse:18.8572
# [140]	validation_0-rmse:18.8571
# [141]	validation_0-rmse:18.8569
# [142]	validation_0-rmse:18.8564
# [143]	validation_0-rmse:18.8562
# [144]	validation_0-rmse:18.8562
# [145]	validation_0-rmse:18.8561
# [146]	validation_0-rmse:18.8563
# [147]	validation_0-rmse:18.8562
# [148]	validation_0-rmse:18.8561
# [149]	validation_0-rmse:18.8562
# [150]	validation_0-rmse:18.8558
# [151]	validation_0-rmse:18.8561
# [152]	validation_0-rmse:18.856
# [153]	validation_0-rmse:18.8562
# [154]	validation_0-rmse:18.856
# [155]	validation_0-rmse:18.8559
# Stopping. Best iteration:
# [150]	validation_0-rmse:18.8558

# %%
grid_model.best_params_
# Out:
# {'model__min_child_weight': 10,
#  'model__max_depth': 7,
#  'model__learning_rate': 0.1,
#  'model__colsample_bytree': 0.9}

# %%
# making predictions using the tuned model
predictions = grid_model.predict(Test_Features[all_cols])

# %% [markdown]
# ---
